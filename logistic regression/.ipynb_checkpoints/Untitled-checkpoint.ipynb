# %% [markdown]
# # Logistic regression on social network ad

# %% [markdown]
# The data shows if a person will purchase the item or not based on gender, age, and salary
# Input Varible:
# User ID
# Gender
# AGe
# EStimated Salary
#
# Output:
# Purchased

# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model  import Ridge,Lasso,RidgeCV, LassoCV, ElasticNet, ElasticNetCV, LogisticRegression
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns
import scikitplot as skl
from sklearn.metrics import confusion_matrix
from matplotlib.colors import ListedColormap
from sklearn.datasets import make_blobs
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
import pickle

import warnings
warnings.filterwarnings('ignore')
sns.set()

# %%
data = pd.read_csv("Social_Network_Ads.csv") # Reading the Data
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
c = pd.get_dummies(data.Gender) # Converting categorical variable into dummy variables
print(c)
# Out:
#      Female  Male
# 0         0     1
# 1         0     1
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 395       1     0
# 396       0     1
# 397       1     0
# 398       0     1
# 399       1     0
#
# [400 rows x 2 columns]

# %%
new_data = pd.concat([data,c], axis=1) # Combing the data

# %%
new_data.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased      Female  \
# count  4.000000e+02  400.000000       400.000000  400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500    0.510000
# std    7.165832e+04   10.482877     34096.960282    0.479864    0.500526
# min    1.556669e+07   18.000000     15000.000000    0.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000    1.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000    1.000000
#
#              Male
# count  400.000000
# mean     0.490000
# std      0.500526
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %%
new_data.isna().sum() # No null values present in the data
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# Female             0
# Male               0
# dtype: int64

# %%
new_data_ = new_data.drop(columns=["User ID","Gender"]) # removing unnecessary data

# %%
# Checking distribution of data

plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in new_data_:
    if plotnumber<=9 :     # as there are 9 columns in the data
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(new_data_[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %%
X = new_data_.drop(columns="Purchased")
y = new_data_["Purchased"]

# %%
# Splitting the dataset into the Training set and Test set

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
# Feature Scaling

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Fitting Logistic Regression to the Training set

classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
accuracy = accuracy_score(y_test,y_pred)

# %%
auc = roc_auc_score(y_test, y_pred)
auc
# Out:
# 0.8841911764705883

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# %%
plt.plot(fpr, tpr, color='orange',label='ROC curve (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--',label='ROC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %%
# Making the Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[65,  3],
#        [ 6, 26]])

# %%
filename = 'finalized_model.pickle'
pickle.dump(classifier, open(filename, 'wb'))

# %%
# prediction using the saved model
loaded_model = pickle.load(open(filename, 'rb'))
a=loaded_model.predict(sc.transform([[30,80000,0,1]]))
print("Will purchase ? (for no 1 for yes)---- {}".format(a))
# Out:
# Will purchase ? (for no 1 for yes)---- [0]

# %%
classifier.predict(sc.transform([[40,80000,1,0]]))
# Out:
# array([0])

# %%
# Performing gridserach cv for best parameters

# %%
# define grid search

# %%
param_grid = [    
    {'penalty' : ['l1', 'l2', 'elasticnet', 'none'],
    'C' : np.logspace(-4, 4, 20),
    'solver' : ['lbfgs','newton-cg','liblinear','sag','saga'],
    'max_iter' : [100, 1000,2500, 5000]
    }
]

# %%
grid_search = GridSearchCV(classifier, param_grid = param_grid, cv = 3, verbose=True, n_jobs=-1)

# %%
grid_result = grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 1600 candidates, totalling 4800 fits
# /Users/milindthoke/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/milindthoke/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/milindthoke/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/milindthoke/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ...

# %%
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.823333 using {'C': 0.0001, 'max_iter': 100, 'penalty': 'none', 'solver': 'lbfgs'}

# %%
final_model = LogisticRegression(C = 0.0001, penalty= 'none', solver ='lbfgs')

# %%
final_model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=0.0001, penalty='none')

# %%
final_model.score(X_test,y_test)
# Out:
# 0.91
